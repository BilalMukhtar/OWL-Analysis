# %%
import pandas as pd

temp = pd.read_csv("original csv files/phs-2022.csv")

# %%
temp
# Out:
#                       start_time  esports_match_id           tournament_title  \
# 0        2022-05-05 19:10:00 UTC             38971  Kickoff Clash: Qualifiers
# 1        2022-05-05 19:10:00 UTC             38971  Kickoff Clash: Qualifiers
# 2        2022-05-05 19:10:00 UTC             38971  Kickoff Clash: Qualifiers
# 3        2022-05-05 19:10:00 UTC             38971  Kickoff Clash: Qualifiers
# 4        2022-05-05 19:10:00 UTC             38971  Kickoff Clash: Qualifiers
# ...                          ...               ...                        ...
# 1124555  2022-11-05 04:16:00 UTC             39362                 Postseason
# 1124556  2022-11-05 04:16:00 UTC             39362                 Postseason
# 1124557  2022-11-05 04:16:00 UTC             39362                 Postseason
# 1124558  2022-11-05 04:16:00 UTC             39362                 Postseason
# 1124559  2022-11-05 04:16:00 UTC             39362                 Postseason
#
# ...

# %%
firsthalf = temp[:int(len(temp)/2)]
secondhalf = temp[int(len(temp)/2):]

# %%
firsthalf
# Out:
#                  start_time  esports_match_id tournament_title map_type  \
# 0       2021-04-16 19:08:52             37234         OWL 2021  CONTROL
# 1       2021-04-16 19:08:52             37234         OWL 2021  CONTROL
# 2       2021-04-16 19:08:52             37234         OWL 2021  CONTROL
# 3       2021-04-16 19:08:52             37234         OWL 2021  CONTROL
# 4       2021-04-16 19:08:52             37234         OWL 2021  CONTROL
# ...                     ...               ...              ...      ...
# 515774  2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515775  2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515776  2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515777  2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515778  2021-07-03 10:25:38             37324         OWL 2021   HYBRID
#
#          map_name player_name            team_name  \
# ...

# %%
secondhalf
# Out:
#                   start_time  esports_match_id tournament_title map_type  \
# 515779   2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515780   2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515781   2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515782   2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# 515783   2021-07-03 10:25:38             37324         OWL 2021   HYBRID
# ...                      ...               ...              ...      ...
# 1031553  2021-09-26 02:53:59             37441         OWL 2021  PAYLOAD
# 1031554  2021-09-26 02:53:59             37441         OWL 2021  PAYLOAD
# 1031555  2021-09-26 02:53:59             37441         OWL 2021  PAYLOAD
# 1031556  2021-09-26 02:53:59             37441         OWL 2021  PAYLOAD
# 1031557  2021-09-26 02:53:59             37441         OWL 2021  PAYLOAD
#
#           map_name player_name            team_name          stat_name  \
# ...

# %%
firsthalf.to_csv("original csv files/phs_2021_p1.csv", index=False)
secondhalf.to_csv("original csv files/phs_2021_p2.csv", index=False)
