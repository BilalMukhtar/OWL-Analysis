# %% [markdown]
# # Creating The Statistic
#
# The goal of the statistic should be to perform the same or even better than the original model did. However, I decided to make a few extra changes:
# * Replaced the "All Heroes" selection in favor of including heroes, as stats vary by hero more than individual performance
# * As referenced above, stats are converted to stats per 10 minutes played to allow for a more even balance

# %%
# Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

stats = pd.read_csv('OWL_stats.csv')
sep_imp = pd.read_csv('sep_imp.csv')

# %%
stat_df = stats.drop(['match_id', 'Final Blows',
                           'Objective Kills', 'All Damage Done',
                            'Ultimates Earned - Fractional', 'team', 'map_name', 'map_type'], axis=1)
stat_df[['Shots Fired', 'Weapon Accuracy', 'Ultimates Used']] = stat_df[['Shots Fired', 'Weapon Accuracy', 'Ultimates Used']].fillna(value=0)
stat_df['Damage Taken'].fillna(value=stat_df['Damage Taken'].mean(), inplace = True)
stat_df.head(5)
# Out:
#       player     hero  Assists  Barrier Damage Done  Damage Taken  Deaths
# 0  Agilities    Genji     17.0          2893.659185   6366.272322    11.0  \
# 1       Envy     D.Va     24.0          4970.275000  17511.894920     8.0
# 2       Fate  Winston     23.0          1486.675676  17838.003230    12.0
# 3      KariV    Mercy      2.0            20.000000   2774.318343     7.0
# 4       SoOn   Tracer     16.0          3361.396517   3933.404831     7.0
#
#    Eliminations  Hero Damage Done  Objective Time  Shots Fired
# 0          32.0      15053.887730       29.617000       1060.0  \
# 1          36.0      11077.082750      117.109998      16030.0
# 2          33.0       8909.393466       77.461999          0.0
# 3           2.0        350.000000       80.310999         39.0
# 4          28.0      11253.140970       69.579999       5628.0
#
#    Time Building Ultimate  Time Elapsed per Ultimate Earned
# 0              694.193020                         77.728449  \
# 1              630.194018                         63.794644
# 2              643.772019                        103.952997
# 3              534.979016                         94.452052
# 4              682.852020                         65.118940
#
#    Time Holding Ultimate  Time Played  Ultimates Used  Weapon Accuracy
# 0              94.136003   836.332770             8.0         0.273585  \
# 1             206.948006   836.332770            23.0         0.314785
# 2             143.093004   836.332770             5.0         0.000000
# 3             217.043006   836.332770             5.0         0.333333
# 4              65.665002   750.675685             9.0         0.376155
#
#    match_winner  map_winner
# 0          True        True
# 1          True        True
# 2          True        True
# 3          True        True
# 4          True        True

# %% [markdown]
# ## First Attempt
#
# For now, the goal is to go basic and utilize the feature importance values in combination with the actual stats:
# * Stats were converted to stats per 10 for better comparison
# * I scaled the feature importances from 0 to 1 and then multiplied those values with each column to produce a new statistic for each player.

# %%
stat_df['Time Played'] = stat_df['Time Played'].multiply(1.0/60.0)

for i in stat_df.columns[2:12]:
    stat_df[i] = stat_df[i].multiply(10.0/stat_df['Time Played'])
    
for i in stat_df.columns[14:15]:
    stat_df[i] = stat_df[i].multiply(10.0/stat_df['Time Played'])

stat_df.drop('Time Played', axis=1, inplace=True)

# %%
print(sep_imp)
# Out:
#                              Feature  Importance
# 0                       Eliminations      0.1358
# 1                             Deaths      0.1164
# 2                            Assists      0.0308
# 3                     Objective Time      0.0160
# 4             Time Building Ultimate      0.0104
# 5                       Damage Taken      0.0084
# 6                   Hero Damage Done      0.0048
# 7              Time Holding Ultimate      0.0042
# 8                Barrier Damage Done      0.0014
# 9                        Shots Fired     -0.0006
# 10                   Weapon Accuracy     -0.0012
# 11                    Ultimates Used     -0.0022
# 12  Time Elapsed per Ultimate Earned     -0.0028

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scale_imp = scaler.fit_transform(sep_imp.to_numpy())
scale_imp[0] *= -1
scale_imp[5] *= -1

x = stat_df.select_dtypes(float).columns
temp = np.dot(stat_df[x], scale_imp)
stat_df['Stat'] = temp
scale_imp
# Out:
#           player        hero    Assists  Barrier Damage Done   Damage Taken
# 0      Agilities       Genji  12.196102          2075.962552    4567.276964  \
# 1           Envy        D.Va  17.218027          3565.763663   12563.344798
# 2           Fate     Winston  16.500609          1066.567565   12797.300699
# 3          KariV       Mercy   1.434836            14.348356    1990.345310
# 4           SoOn      Tracer  12.788479          2686.696732    3143.891491
# ...          ...         ...        ...                  ...            ...
# 26024      carpe  Widowmaker   1.751386           227.680132    2974.136660
# 26025        eqo      Pharah   2.922108          2092.229156    4086.674323
# 26026        eqo      Tracer   3.129015           549.341628    3173.392424
# 26027    neptuNo       Lúcio        NaN                  NaN  254368.675198
# 26028    neptuNo       Mercy   1.548960           108.427166    3978.932660
#
#           Deaths  Eliminations  Hero Damage Done  Objective Time
# 0       7.891596     22.957369      10799.926734       21.247762  \
# 1       5.739342     25.827040       7946.896129       84.016795
# 2       8.609013     23.674787       6391.757292       55.572615
# 3       5.021924      1.434836        251.096223       57.616539
# 4       5.594959     22.379838       8994.409591       55.613896
# ...          ...           ...               ...             ...
# 26024  10.508314      5.254157       6776.657119        5.357489
# 26025   8.766323      2.922108       5171.774021        4.193225
# 26026   9.387044      9.387044       5928.466699       68.469099
# 26027        NaN           NaN               NaN             NaN
# 26028   6.195838      1.548960       1112.152928       19.007283
#
#         Shots Fired  Time Building Ultimate  Time Elapsed per Ultimate Earned
# 0        760.462848              498.026416                         55.763771  \
# 1      11500.207033              452.112394                         45.767412
# 2          0.000000              461.853493                         74.577728
# 3         27.979293              383.803458                         67.761582
# 4       4498.347378              545.789907                         52.048261
# ...             ...                     ...                               ...
# 26024    243.442603              511.218973                        166.767755
# 26025    280.522345              487.334536                        384.843147
# 26026   4217.911675              510.583230                        223.417399
# 26027      0.000000              720.140957                      42008.221819
# 26028     69.703178              491.142547                        117.978214
#
#        Time Holding Ultimate  Ultimates Used  Weapon Accuracy  match_winner
# 0                  94.136003        5.739342         0.273585          True  \
# 1                 206.948006       16.500609         0.314785          True
# 2                 143.093004        3.587089         0.000000          True
# 3                 217.043006        3.587089         0.333333          True
# 4                  65.665002        7.193519         0.376155          True
# ...                      ...             ...              ...           ...
# 26024               7.358000        5.254157         0.596774         False
# 26025              38.926001        0.000000         0.323944         False
# 26026              27.958001        6.258029         0.406306         False
# 26027                    NaN        0.000000         0.000000         False
# 26028              19.212001        6.195838         0.621622         False
#
#        map_winner         Stat
# 0            True -1478.776733
# 1            True   -40.404693
# 2            True  1708.408497
# 3            True   471.929529
# 4            True -2011.230162
# ...           ...          ...
# 26024       False    12.094969
# 26025       False -1186.476752
# 26026       False    59.234527
# 26027       False          NaN
# 26028       False   805.572188
#
# [26029 rows x 18 columns]

# %% [markdown]
# Some players did not have enough play time to register stats, and as such will not have a statistic for their play

# %%
stat_df = stat_df[stat_df['Stat'].notna()]
stat_df.head(5)
# Out:
#       player     hero    Assists  Barrier Damage Done  Damage Taken    Deaths
# 0  Agilities    Genji  12.196102          2075.962552   4567.276964  7.891596  \
# 1       Envy     D.Va  17.218027          3565.763663  12563.344798  5.739342
# 2       Fate  Winston  16.500609          1066.567565  12797.300699  8.609013
# 3      KariV    Mercy   1.434836            14.348356   1990.345310  5.021924
# 4       SoOn   Tracer  12.788479          2686.696732   3143.891491  5.594959
#
#    Eliminations  Hero Damage Done  Objective Time   Shots Fired
# 0     22.957369      10799.926734       21.247762    760.462848  \
# 1     25.827040       7946.896129       84.016795  11500.207033
# 2     23.674787       6391.757292       55.572615      0.000000
# 3      1.434836        251.096223       57.616539     27.979293
# 4     22.379838       8994.409591       55.613896   4498.347378
#
#    Time Building Ultimate  Time Elapsed per Ultimate Earned
# 0              498.026416                         55.763771  \
# 1              452.112394                         45.767412
# 2              461.853493                         74.577728
# 3              383.803458                         67.761582
# 4              545.789907                         52.048261
#
#    Time Holding Ultimate  Ultimates Used  Weapon Accuracy  match_winner
# 0              94.136003        5.739342         0.273585          True  \
# 1             206.948006       16.500609         0.314785          True
# 2             143.093004        3.587089         0.000000          True
# 3             217.043006        3.587089         0.333333          True
# 4              65.665002        7.193519         0.376155          True
#
#    map_winner         Stat
# 0        True  2269.022405
# 1        True  6598.945457
# 2        True  4163.623834
# 3        True   611.245849
# 4        True  2674.538205

# %% [markdown]
# ### Comparison
#
# Based on the accuracy score, it is clear the stat is not much better than randomly selecting a win or loss, and this is evidenced by the confusion matrix which shows an even distribution within all possible outcomes.

# %%
y_match = stat_df['match_winner'] # Predicts match wins
y_map = stat_df['map_winner'] # Predicts map wins

X = stat_df[['Stat']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_match, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf_clf = RandomForestClassifier(n_jobs=-1, n_estimators=300)
rf_clf.fit(X_train, y_train)

print('Train accuracy score:', accuracy_score(y_train, rf_clf.predict(X_train)))
print('Test accuracy score:', accuracy_score(y_test, rf_clf.predict(X_test)))
# Out:
# Train accuracy score: 0.9966167230546158
# Test accuracy score: 0.5235180412371134

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = rf_clf.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=rf_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf_clf.classes_)

disp.plot()
plt.show()

# %% [markdown]
# ### Conclusion
#
# The main issue from looking at individuals stats in comparison to the combined stat is that certain stats are easier to accumulate (hero damage, shots fired) than other stats (eliminations, deaths). While easier to accumulate stats appear to have less importance, when simply scaled and multiplied, their importance becomes much more significant, so all of the stats may need to be scaled to give a more accurate depiction for a stat.

# %% [markdown]
# ## Second Attempt
#
# This time around, the stat will be hero-dependent, which should provide a more even playing field and thus create better predictions:
# * First, stats were scaled from 0 to 100 so stats with larger ranges had a smaller impact overall
# * Second, I incorrectly created the stat initially, so the columns are correctly aligned for the proper dot product to be calculated this time

# %%
stat_df = stats.drop(['Final Blows',
                           'Objective Kills', 'All Damage Done',
                            'Ultimates Earned - Fractional'], axis=1)
stat_df[['Shots Fired', 'Weapon Accuracy', 'Ultimates Used']] = stat_df[['Shots Fired', 'Weapon Accuracy', 'Ultimates Used']].fillna(value=0)
stat_df['Damage Taken'].fillna(value=stat_df['Damage Taken'].mean(), inplace = True)

# %%
from sklearn.preprocessing import MinMaxScaler

stat_df['Time Played'] = stat_df['Time Played'].multiply(1.0/60.0)

for i in stat_df.columns[6:16]:
    stat_df[i] = stat_df[i].multiply(10.0/stat_df['Time Played'])
    scaler = MinMaxScaler(feature_range=(0,100))
    stat_df[i] = scaler.fit_transform(stat_df[[i]].to_numpy())
    
for i in stat_df.columns[18:19]:
    stat_df[i] = stat_df[i].multiply(10.0/stat_df['Time Played'])
    scaler = MinMaxScaler(feature_range=(0,100))
    stat_df[i] = scaler.fit_transform(stat_df[[i]].to_numpy())

stat_df.drop('Time Played', axis=1, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
from pandas import Index

scaler = MinMaxScaler()
features = sep_imp['Feature']
temp = sep_imp.drop('Feature', axis=1)
scale_imp = scaler.fit_transform(temp.to_numpy())
scale_imp[Index(sep_imp['Feature']).get_loc('Deaths')] *= -1
scale_imp[Index(sep_imp['Feature']).get_loc('Damage Taken')] *= -1

first_set = stat_df[stat_df.columns[0:6]]
match = stat_df['match_winner']
maps = stat_df['map_winner']

stat_df = stat_df.reindex(columns=features)
x = stat_df.select_dtypes(float).columns
temp = np.dot(stat_df[x], scale_imp)
stat_df['Stat'] = temp
stat_df = stat_df[stat_df['Stat'].notna()]

temp = pd.DataFrame(stat_df) # To allow for name resusage
stat_df = first_set.merge(temp, how='inner', left_index=True, right_index=True)
stat_df['match_winner'] = match
stat_df['map_winner'] = maps
stat_df.drop('Time Holding Ultimate', axis=1, inplace=True)

# %%
heroes = stat_df['hero'].unique()
averages = {}

for hero in heroes:
    hero_df = stat_df[stat_df['hero'] == hero]
    averages[hero] = hero_df['Stat'].mean()

# %%
from sklearn.preprocessing import MinMaxScaler
def func(stat, hero):
    return stat * 1.0/averages[hero]

stat_df['Stat'] = stat_df.apply((lambda x: func(x['Stat'], x['hero'])), axis=1)
dfs = {}

for hero in heroes:
    cur = stat_df[stat_df['hero'] == hero]
    scaler = MinMaxScaler(feature_range=(30,100))
    cur['Stat'] = scaler.fit_transform(cur[['Stat']].to_numpy())
    dfs[hero] = cur
    
stat_df = pd.concat(dfs.values())

# %%
stat_df[stat_df['hero']=='Winston'].sort_values(by='Stat', ascending=False)
# Out:
#        match_id               map_name map_type                 team  player
# 17197     10475  Watchpoint: Gibraltar  PAYLOAD      Boston Uprising   Gamsu  \
# 3541      10259                 Dorado  PAYLOAD  Los Angeles Valiant    Fate
# 20187     10566            Eichenwalde   HYBRID  Los Angeles Valiant    Fate
# 9472      10335                  Ilios  CONTROL  San Francisco Shock   super
# 9442      10334       Temple of Anubis  ASSAULT  Los Angeles Valiant    Fate
# ...         ...                    ...      ...                  ...     ...
# 20262     10567            Eichenwalde   HYBRID  Philadelphia Fusion   fragi
# 4411      10268            Eichenwalde   HYBRID     Shanghai Dragons  Roshan
# 17482     10478   Horizon Lunar Colony  ASSAULT       Florida Mayhem     SNT
# 16839     10472   Horizon Lunar Colony  ASSAULT  Philadelphia Fusion    SADO
# 13064     10373             Junkertown  PAYLOAD  San Francisco Shock    Nomy
#
#           hero  Eliminations     Deaths    Assists  Objective Time
# 17197  Winston      6.431582   2.583610   6.534300       10.504059  \
# 3541   Winston     13.234599   0.942606  15.931658       15.189586
# 20187  Winston     11.996959   2.629975  12.116602       13.140824
# 9472   Winston     18.598805   1.198458  21.529580       13.301588
# 9442   Winston     22.918602   1.834087  32.947729       12.393333
# ...        ...           ...        ...        ...             ...
# 20262  Winston      2.504108   8.078884   3.879553        1.963035
# 4411   Winston      2.221801   7.740883   3.442182        1.062979
# 17482  Winston      1.372703   8.076552   2.126694        5.118901
# 16839  Winston      0.843946   8.067610   1.307504        4.003117
# 13064  Winston      2.184852  10.812608   3.384937        2.556348
#
#        Time Building Ultimate  Damage Taken  Hero Damage Done
# 17197                8.070831      0.332348         10.938619  \
# 3541                 8.975804      0.278030         10.340823
# 20187                7.490065      0.326947          9.405457
# 9472                 9.197432      0.277425          9.892135
# 9442                13.972067      0.156601          5.724240
# ...                       ...           ...               ...
# 20262               17.681598      0.294735          4.395611
# 4411                17.148464      0.343482          5.429137
# 17482               17.920078      0.271690          2.710019
# 16839               17.093064      0.374186          2.566183
# 13064               16.940148      0.376221          7.903236
#
#        Barrier Damage Done  Shots Fired  Weapon Accuracy  Ultimates Used
# 17197             1.952696          0.0              0.0        9.199377  \
# 3541              1.222995          0.0              0.0       11.354910
# 20187             2.086458          0.0              0.0        8.898858
# 9472              1.437831          0.0              0.0       12.211814
# 9442              0.865294          0.0              0.0        0.000000
# ...                    ...          ...              ...             ...
# 20262             0.449889          0.0              0.0        6.265898
# 4411              1.442289          0.0              0.0        8.421307
# 17482             2.003603          0.0              0.0        0.000000
# 16839             2.288121          0.0              0.0        7.300459
# 13064             1.406493          0.0              0.0        8.293364
#
#        Time Elapsed per Ultimate Earned        Stat  match_winner  map_winner
# 17197                          0.003461  100.000000         False       False
# 3541                           0.005843   99.293624          True        True
# 20187                          0.006367   99.173909          True        True
# 9472                           0.012689   96.614285          True        True
# 9442                           0.069674   95.561800          True        True
# ...                                 ...         ...           ...         ...
# 20262                          0.039496   34.094392         False       False
# 4411                           0.052925   33.962135         False       False
# 17482                          0.083469   32.290785         False        True
# 16839                          0.060603   30.954319         False       False
# 13064                          0.040493   30.000000         False       False
#
# [1926 rows x 21 columns]

# %%
stat_df.sort_values(by='Stat', ascending=False)
# Out:
# Feature     player      hero  Eliminations    Deaths    Assists
# 24882         Neko   Bastion     11.662827  3.762015  10.071271  \
# 647           Fate     Orisa     12.555106  4.574063  13.071638
# 25989       Profit  Brigitte     20.250263  1.066799  24.699775
# 6464     ryujehong     Moira     20.230783  1.727804  24.034881
# 1149         Fleta    Tracer     38.736776  7.052303  51.393982
# ...            ...       ...           ...       ...        ...
# 16703       Mickie  Brigitte      1.284479  9.599676   1.990011
# 14537      STRIKER     Hanzo      2.252167  9.484520   3.489226
# 13189      neptuNo     Lúcio      1.291787  9.648426   2.001334
# 11162        ZUNBA   Roadhog      1.950685  8.278018   3.022148
# 25779       JJonak  Zenyatta      1.458785  8.535875   2.260059
#
# Feature  Objective Time  Time Building Ultimate  Damage Taken
# 24882         35.151668                7.601884      0.208852  \
# 647           28.561693               12.916165      0.229351
# 25989         36.109480               14.244228      0.143100
# 6464          45.304021               10.494450      0.165844
# 1149          52.261826               17.969092      0.077573
# ...                 ...                     ...           ...
# 16703          5.053052               17.070393      0.225379
# 14537          2.895000               16.152443      0.144293
# 13189          3.168668               17.335200      0.145521
# 11162          4.803364               17.860059      0.387998
# 25779          0.036682               16.885365      0.090960
#
# Feature  Hero Damage Done  Barrier Damage Done  Shots Fired  Weapon Accuracy
# 24882           16.796820            22.216995    19.484324         0.291794  \
# 647              7.714988             4.382609     8.131037         0.302396
# 25989            8.247258             1.333492     0.000000         0.000000
# 6464             6.942925             0.614438     0.000000         0.000000
# 1149            20.541247             3.125665    20.772727         0.410959
# ...                   ...                  ...          ...              ...
# 16703            4.888142             1.894422     0.000000         0.000000
# 14537           12.475064            14.478326     1.721127         0.192982
# 13189            5.698718             4.619563     3.047134         0.346821
# 11162            5.310088             8.497549    15.196110         0.247544
# 25779            9.966689             3.730778     1.678735         0.411111
#
# Feature  Ultimates Used  Time Elapsed per Ultimate Earned   Stat
# 24882         10.725022                          0.010782  100.0  \
# 647            7.129397                          0.005626  100.0
# 25989         14.915400                          0.023969  100.0
# 6464          21.778676                          0.027791  100.0
# 1149          38.531738                          0.067095  100.0
# ...                 ...                               ...    ...
# 16703         10.351310                          0.060117   30.0
# 14537         17.052904                          0.079371   30.0
# 13189         10.401927                          0.051953   30.0
# 11162         14.965032                          0.088152   30.0
# 25779         11.558444                          0.049143   30.0
#
# Feature  match_winner  map_winner
# 24882            True        True
# 647              True        True
# 25989            True        True
# 6464             True        True
# 1149             True        True
# ...               ...         ...
# 16703           False       False
# 14537           False       False
# 13189           False       False
# 11162           False       False
# 25779           False       False
#
# [15518 rows x 17 columns]

# %% [markdown]
# ### Comparison
#
# Compared to the previous attempt, there appears to be a 10% gain in the accuracy of the model compared to the first attempt

# %%
y_match = stat_df['match_winner'] # Predicts match wins
y_map = stat_df['map_winner'] # Predicts map wins

X = stat_df[['Stat']]



from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_map, test_size=0.2, random_state=42)




from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf_clf = RandomForestClassifier(n_jobs=-1, n_estimators=300)
rf_clf.fit(X_train, y_train)

print('Train accuracy score:', accuracy_score(y_train, rf_clf.predict(X_train)))
print('Test accuracy score:', accuracy_score(y_test, rf_clf.predict(X_test)))



from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = rf_clf.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=rf_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf_clf.classes_)

disp.plot()
plt.show()
# Out:
# Train accuracy score: 0.9990333494441759
# Test accuracy score: 0.5776417525773195

# %% [markdown]
# ### Saving for use in part 3

# %%
stat_df.to_csv('stat_df.csv', index=False)
